# %%
from PIL import Image
import requests
from io import BytesIO
import matplotlib.pyplot as plt
# %matplotlib inline

response = requests.get('https://phonoteka.org/uploads/posts/2021-07/1625614006_10-phonoteka-org-p-boruto-art-krasivo-11.jpg')
img = Image.open(BytesIO(response.content))

plt.imshow(img)
